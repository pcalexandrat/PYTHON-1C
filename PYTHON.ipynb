# %% [markdown]
# <a href="https://colab.research.google.com/github/pcalexandrat/PYTHON-1C/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AULA 1** ✅ :  💪   📓   🙂
#
# ![image.png](data:image/png;base64,...)

# %%
ano = "IX"
print(ano, "competição de programação dá Start")
# Out:
# IX competição de programação dá Start

# %%
print("Sou seu assitente virtual,  \n ")
nome = (input("Digite seu nome: "))
print(f"Olá, {nome}. Qual é sua dúvida hoje?")
resposta = input("Qual o assunto que deseja tratar: Matemática, Python, Javascript ").lower()
print(f"Que bom, {nome}, vamos falar sobre {resposta}")
if resposta=="python":
  print("Òtimo, vamos falar sobre Python. \n Python é uma linguagem de programação de alto nível, conhecida por sua sintaxe clara,legível e poderosa.\n Ela se destaca amplamente em campos que exigem intensa manipulação numérica e análise de dados, como Ciência de Dados, Engenharia e Inteligência Artificial.\n Isso é possível graças ao seu rico ecossistema de bibliotecas especializadas, como NumPy e SciPy, que oferecem funções matemáticas e estatísticas avançadas,\n tornando-a a escolha ideal para computação científic")
elif resposta=="javascript":
  print("Que legal, vamos falar sobre Javascript. \n JavaScript é a linguagem de programação primária da web, responsável por tornar as páginas interativas.\n Embora seja mais conhecida pelo desenvolvimento front-end (navegadores), ela é fundamental para executar cálculos rápidos e dinâmicos.\n Além das operações aritméticas básicas, o objeto Math do JavaScript oferece diversas funções para trigonometria e manipulação de números.\n Com o Node.js, JavaScript também é usado no lado do servidor, processando lógica de negócios que, frequentemente, envolve regras e cálculos matemáticos.")
elif resposta=="matemática":
  print("Interessante, vamos falar sobre Matemática! \n A matemática é a linguagem universal que serve como fundamento lógico para todas as ciências e tecnologias.\n Ela fornece os conceitos, as regras e as ferramentas (como álgebra, estatística e cálculo) necessárias para\n resolver problemas, modelar fenômenos do mundo real e, essencialmente, estruturar a lógica de qualquer\n programa de computador, desde a simples soma até algoritmos complexos de Machine Learning.")
else:
  print("Que pena... não sei falar sobre esse assunto :/")
# Out:
# Sou seu assitente virtual,
#
# Digite seu nome: Ale
# Olá, Ale. Qual é sua dúvida hoje?
# Qual o assunto que deseja tratar: Matemática, Python, Javascript Python
# Que bom, Ale, vamos falar sobre python
# Òtimo, vamos falar sobre Python.
#  Python é uma linguagem de programação de alto nível, conhecida por sua sintaxe clara,legível e poderosa.
#  Ela se destaca amplamente em campos que exigem intensa manipulação numérica e análise de dados, como Ciência de Dados, Engenharia e Inteligência Artificial.
#  Isso é possível graças ao seu rico ecossistema de bibliotecas especializadas, como NumPy e SciPy, que oferecem funções matemáticas e estatísticas avançadas,
#  tornando-a a escolha ideal para computação científic

# %% [markdown]
# Aula 7 - Listas ⚛ ♈ ⏰

# %%
import random
dicas = [
    "Seja feliz e não incomode o próximo, ele não merece 🥰",
    "Gaste sua energia com coisas boas, pensamentos positivos 😘",
    "Respire fundo, agradeça, sorria para o próximo, ele merece, ou precisa 🧡",
    "🌞 Não espere o momento perfeito — faça do agora a sua melhor oportunidade.",
    "💫 Você é capaz de transformar esforço em conquista e sonho em realidade.",
    "✨ A cada passo, mesmo pequeno, você se aproxima de algo grandioso. Continue acreditando no seu caminho.",
    "🌱 Os dias difíceis também fazem florescer força, coragem e sabedoria dentro de você.",
 ]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()

  if pedido == "dica":
    dica = random.choice(dicas) # escolhe uma dica aleatória sair
    print(f"Dica: {dica} \n")
    break
  elif pedido == "sair":
    print("Até a próxima! \n")
    break
  else:
    print("Comando inválido. Tente novamente. \n")
    break
